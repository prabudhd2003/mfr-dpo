# %% [markdown]
# # Build the frozen-reference cache
# GPU required, but run only once after `data/v2` is frozen. This stores the base model's chosen/rejected log probabilities so every experiment avoids repeating that work. The manifest prevents use with different data or model revisions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, subprocess
if not os.path.exists('/content/mfr-dpo'):
    # !git clone -q https://github.com/prabudhd2003/mfr-dpo.git /content/mfr-dpo
elif subprocess.run(['git', '-C', '/content/mfr-dpo', 'status', '--porcelain', '--', 'data/v2'], capture_output=True, text=True, check=True).stdout.strip():
    print('Keeping local data/v2; skipping git pull so it is not overwritten.')
else:
    # !git -C /content/mfr-dpo pull --ff-only -q
# !pip install -q -r /content/mfr-dpo/requirements.txt
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/mfr-dpo'
OUTPUT = '/content/drive/MyDrive/CSCI544/mfr-dpo/cache/reference_v2.csv'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 63.7 MB/s eta 0:00:00:00:0100:01
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
subprocess.run(['python', f'{REPO}/scripts/build_reference_cache.py', '--output', OUTPUT], check=True)
print('Saved:', OUTPUT)
# Out:
# Saved: /content/drive/MyDrive/CSCI544/mfr-dpo/cache/reference_v2.csv
